# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Prep-AIMS-Cmr-2024-25">Quiz 4, Data Prep, AIMS Sen25 </h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# ### LEKOUNDA NGOLO Mardochet Gedeon
# ##

# %% [markdown]
# # Travailler avec les Données Temporelles

# %% [markdown]
# ## 1. Convertissez la chaîne de date suivante `"2024#12#25"` en utilisant `pd.to_datetime()` avec le paramètre de format approprié.

# %%
import pandas as pd

# %%
pd.to_datetime('2024#25#12' , 
               format = '%Y#%d#%m' )
# Out:
# Timestamp('2024-12-25 00:00:00')

# %% [markdown]
# ## 2. Convertissez la chaîne `"December-25-2024"` en `pandas Timestamp` en utilisant la spécification de format correcte.

# %%
pd.Timestamp('December-25-2024')
# Out:
# Timestamp('2025-12-25 00:00:00')

# %%
pd.Timestamp('2025 December 25'  ) # ou encore Option 2 (pd.Timestamp est flexible)
# Out:
# Timestamp('2024-12-25 00:00:00')

# %% [markdown]
# ## 3. Exécutez la commande ci-dessous pour générer un dataframe

# %%
import numpy as np
my_initial_df = pd.DataFrame({'year': list(np.random.randint(2000,2025,10)), 
                   'month': list(np.random.randint(1,13,10)), 
                   'day': list(np.random.randint(1,29,10)), 
                   'hour': list(np.random.randint(0,24,10)), 
                   'meal_menu': ['mafe', 'yassa', 'cebon', 'soup', 'mafe', 'grilled fish', 'grilled fish', 'yassa', 'cebon', 'soup']})
my_initial_df['date'] = pd.to_datetime(my_initial_df[['year', 'month', 'day', 'hour']])

my_initial_df = my_initial_df.drop(columns=['year', 'month', 'day', 'hour'])
my_initial_df = my_initial_df[['date', 'meal_menu']].unique()
my_initial_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_155609/1438808049.py in ?()
#       6                    'meal_menu': ['mafe', 'yassa', 'cebon', 'soup', 'mafe', 'grilled fish', 'grilled fish', 'yassa', 'cebon', 'soup']})
#       7 my_initial_df['date'] = pd.to_datetime(my_initial_df[['year', 'month', 'day', 'hour']])
#       8
#       9 my_initial_df = my_initial_df.drop(columns=['year', 'month', 'day', 'hour'])
# ---> 10 my_initial_df = my_initial_df[['date', 'meal_menu']].unique()
#      11 my_initial_df
#
# ~/.conda/envs/data_prep/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...

# %% [markdown]
# ## Utilisez .unique() pour afficher tous les menus de repas distincts qui sont listés dans le dataframe

# %%
my_initial_df['meal_menu'].unique()
# Out:
# array(['mafe', 'yassa', 'cebon', 'soup', 'grilled fish'], dtype=object)

# %% [markdown]
# ## 4. À quelle(s) date(s) ont-ils cuisiné le repas nommé `'grilled fish'`?
# Écrivez le code pour cela.

# %%
date_meal  = my_initial_df[ my_initial_df['meal_menu']=='grilled fish' ]
date_meal
# Out:
#                  date     meal_menu
# 5 2001-06-15 08:00:00  grilled fish
# 6 2015-10-08 00:00:00  grilled fish

# %% [markdown]
# ## 5. À quel(s) nom(s) de jour cela correspond-il exactement?
# (Indice : vous pouvez utiliser `data_frame['column_name'].dt.day_name()`)

# %%
date_meal  = my_initial_df[ my_initial_df['meal_menu']=='grilled fish' ]
date_meal['date'].dt.day_name()
# Out:
# 5      Friday
# 6    Thursday
# Name: date, dtype: object

# %% [markdown]
# ## Supposons que vous ayez la date suivante à analyser : `'2025 KEUR 12***04'`. Exécutez le code ci-dessous

# %%
saly_date_coerce = pd.to_datetime('2025 KEUR 12***04', format='%Y KEUR %m--%d',
                   errors='coerce')
saly_date_coerce
# Out:
# NaT

# %%
"""
A la sortie nous remarque NaT qui signifie : pas de valeur assignée

"""

# %% [markdown]
# ## 6. Nous avons passé `ignore` comme paramètre. Décrivez ce qui se passe exactement?

# %%
saly_date_ignore = pd.to_datetime('2025 KEUR 12***04', format='%Y KEUR %m--%d',
                   errors='ignore')
saly_date_ignore
# Out:
# /tmp/ipykernel_155609/2780511070.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   saly_date_ignore = pd.to_datetime('2025 KEUR 12***04', format='%Y KEUR %m--%d',
# '2025 KEUR 12***04'

# %%
"""
nous remarquons une erreur , une exception a été lévé
et ipykernel (le kernel) nous averti que l'argument 'ignore' est deprecier, et ne sera plus utilise dans les prochaines versions
"""

# %% [markdown]
# ## 7. Nous avons passé `raise` comme paramètre. Décrivez ce qui se passe exactement?

# %%
saly_date_raise = pd.to_datetime('2025 KEUR 12***04', format='%Y KEUR %m--%d',
                   errors='raise')
saly_date_raise
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 saly_date_raise = pd.to_datetime('2025 KEUR 12***04', format='%Y KEUR %m--%d',
#       2                    errors='raise')
#       3 saly_date_raise
#
# File ~/.conda/envs/data_prep/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1101, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099         result = convert_listlike(argc, format)
#    1100 else:
# -> 1101     result = convert_listlike(np.array([arg]), format)[0]
#    1102     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1103         result = bool(result)  # TODO: avoid this kludge.
#
# ...

# %%
""" 
Une exception de type 'valueError' a ete lévé.
cela est du a une erreur de value entré par rapport  a la valeur attendue par le programme

"""

# %% [markdown]
# ## 8. Fournissez le format approprié pour résoudre le problème.

# %%
saly_date = pd.to_datetime('2025 KEUR 12***04', 
                           format = '%Y KEUR %d***%m')
saly_date
# Out:
# Timestamp('2025-04-12 00:00:00')

# %% [markdown]
# ## 9. Créez un objet Timedelta représentant : `5 jours, 3 heures et 30 minutes` et ajoutez-y `deux semaines 10 minutes`.

# %%
def_1 = pd.Timedelta('5 Day 3hour 30min ')
def_1
# Out:
# Timedelta('5 days 03:30:00')

# %%
def_2 = pd.Timedelta(2, unit="W") + pd.Timedelta(10, unit="min")

total = def_2 + def_1 

total
# Out:
# Timedelta('19 days 03:40:00')

# %% [markdown]
# ## 10. Générez une plage de dates commençant le `'2025-11-05'` avec une période de tous les 4 jours jusqu'au `30 décembre 2025`.

# %%
day_delays = pd.DataFrame(pd.date_range("2025/11/05", "2025/12/30" , freq='4D'))
day_delays
# Out:
#             0
# 0  2025-11-05
# 1  2025-11-09
# 2  2025-11-13
# 3  2025-11-17
# 4  2025-11-21
# 5  2025-11-25
# 6  2025-11-29
# 7  2025-12-03
# 8  2025-12-07
# 9  2025-12-11
# 10 2025-12-15
# 11 2025-12-19
# 12 2025-12-23
# 13 2025-12-27
