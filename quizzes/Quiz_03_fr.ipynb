# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Prep-AIMS-Cmr-2024-25">Quiz 3, Data Prep, AIMS Sen25 </h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# Vous avez accès au jeu de données `gapminder` pour comprendre certaines tendances et extraire des insights.
#
# Pour chacune des questions, fournissez les codes Python correspondants.

# %% [markdown]
# ### LEKOUNDA NGOLO Mardochet Gedeon

# %%
import pandas as pd
gapminder_df = pd.read_csv('data/gapminder.tsv', sep='\t')
gapminder_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### 1. Quel pays asiatique avait un PIB supérieur à la médiane européenne dans la décennie 2000 ?

# %%
gap_asia = gapminder_df[ gapminder_df['continent']== 'Asia']
gap_europe = gapminder_df[ gapminder_df['continent']== 'Europe']
gap_asia_2000 = gap_asia[ gap_asia['year'].between(2000,2010 , insclusive='left')]
gap_europe_2000 = gap_asia[ gap_europe['year'].between(2000,2010 , insclusive='left')]
most_pib_asia = gap_asia_2000[ gap_asia_2000['gdpPercap'] > gap_europe_2000 ['gdpPercap'].median()]

# %% [markdown]
# ## 2. Dans la decennie 1990, combien de pays africains avaient une espérance de vie supérieure à la moyenne mondiale pour cette décennie ?

# %%
df_africa =gapminder_df[ gapminder_df['continent']== 'Africa']
df_africa_90 = df_africa [df_africa['year'].between(1990,2000 , inclusive='both')]
df_africa_90 = df_africa_90[ df_africa_90['lifeExp'] > gapminder_df['lifeExp'].mean()]

# %% [markdown]
# ## Le code ci-dessous crée un graphique en barres groupées qui visualise les tendances du PIB par habitant pour trois pays d'Afrique de l'Ouest (Sénégal, Guinée et Gambie) à travers cinq points temporels spécifiques (1977, 1982, 1987, 1992, 1997, 2002, 2007).

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the countries and years of interest
west_african_countries = ['Benin', 'Guinea', 'Togo']
target_years = [1977, 1982 ,1987, 1992, 1997, 2002, 2007]

# Filter data for the specified countries and years
df_wa = gapminder_df[gapminder_df['country'].isin(west_african_countries)]
df_filtered = df_wa[df_wa['year'].isin(target_years)]

# Pivot the data to have countries as columns and years as index
gdp_pivot = df_filtered.pivot(index='year', columns='country', values='gdpPercap')

# Create the grouped bar plot
gdp_pivot.plot(kind='bar', figsize=(10, 6))
plt.title('GDP per Capita Distribution for West African Countries (1987-2007)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita (USD)')
plt.legend(title='Country' ,loc = 'upper center')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Basé sur le graphique ci-dessus, quel pays avait le PIB par habitant le plus élevé en 2007 ? Lequel avait le plus faible ?

# %%
## Selon mon observation 
## Le pays ayant le PIB le plus eleve c'etait le Benin avec 1400 GDP (USD)
## Le pays ayant le PIB le plus faible c'est le TOGO avec environ 800+ GDP (USD)

# %% [markdown]
# ### 4. Décrivez la tendance générale pour chaque pays de 1977 à 2007. Sont-elles en augmentation, en diminution, fluctuantes ou plus ou moins stables ? Quels insights pouvez-vous tirer de chacune de vos observations ?

# %%
#Description de la tendance generake pour chaque pays de 1977 2007
"""
Les données observé nous indiquent la tendance est fluctuante pour le Benin 
Le PIB est en baisse pour le Togo
Le PIB est plus ou moins stable pour la Guinnée
"""

# %% [markdown]
# ### 5. Imaginez que vous êtes un conseiller financier en 1987. Un investisseur vous approche pour demander conseil sur un plan d'investissement de 5 ans (1987-1992) dans l'un des trois pays d'Afrique de l'Ouest montrés dans le graphique ci-dessus : Bénin, Guinée, ou Togo. Basé sur les tendances du PIB par habitant visibles dans les données, classez ces trois pays du plus attractif au moins attractif pour l'investissement. Fournissez votre raisonnement pour chaque classement.

# %%
"""
Benin
guinne 
Togo

"""
