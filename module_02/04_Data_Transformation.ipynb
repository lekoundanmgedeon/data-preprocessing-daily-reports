# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Science-AIMS-Cmr-2021-22">Chapter 4:
#     Data Transformation and Feature Engineering</h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lesson, you will:
# - Create new columns and derived features from existing data
# - Master string operations for text processing
# - Handle categorical data effectively
# - Perform grouping and aggregation operations
# - Merge and join datasets from multiple sources
# - Apply feature engineering techniques to African business datasets

# %% [markdown]
# ## Introduction: The Art of Feature Engineering
#
# Feature engineering is often considered the most important skill in data science. It's the process of creating new variables (features) from existing data to better represent the underlying patterns and relationships.
#
# In the African context, this might mean:
# - Creating **seasonal indicators** from dates for agricultural data
# - Calculating **profit margins** from revenue and cost data for businesses
# - Deriving **population density** from population and area data for urban planning
# - Extracting **age groups** from birth dates for demographic analysis
#
# Let's explore these techniques with real African datasets!

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
plt.style.use('default')
sns.set_palette("husl")

print("Libraries imported successfully!")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
# Out:
# Libraries imported successfully!
# pandas version: 2.2.3
# numpy version: 2.2.5

# %% [markdown]
# ## Dataset 1: Nigerian Small Business Data
#
# Let's start with a dataset representing small businesses across Nigeria, including revenue, costs, and operational data.

# %%
df_nigeria =pd.read_csv(filepath_or_buffer ='data/naija_businesses.csv')
df_nigeria.head()
# Out:
#   business_id business_name   state  business_type  start_date  \
# 0     NG_0001    Business_1   Benue         Retail  2023-02-01
# 1     NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2     NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3     NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4     NG_0005    Business_5  Rivers     Technology  2022-11-28
#
#    monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                 417741               406718          8        False
# 1                 696804               256593         10         True
# 2                 520713                87719         11        False
# 3                 553527               389310          7        False
# 4                 231537               -11869         10         True
#
#    accepts_mobile_money
# 0                  True
# 1                 False
# 2                  True
# 3                  True
# 4                 False

# %% [markdown]
# ## 1. Creating New Columns
#
# Let's start by creating new features from existing data:

# %%
# 1. Calculate profit and profit margin
df_nigeria['monthly_profit_naira'] = df_nigeria['monthly_revenue_naira'] - df_nigeria['monthly_costs_naira']
df_nigeria['profit_margin_percent'] = round((df_nigeria['monthly_profit_naira'] / df_nigeria['monthly_revenue_naira']) * 100 , 2)
df_nigeria
# Out:
#     business_id business_name   state  business_type  start_date  \
# 0       NG_0001    Business_1   Benue         Retail  2023-02-01
# 1       NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2       NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3       NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4       NG_0005    Business_5  Rivers     Technology  2022-11-28
# ..          ...           ...     ...            ...         ...
# 195     NG_0196  Business_196    Kano       Services  2023-09-27
# 196     NG_0197  Business_197    Kano    Agriculture  2021-01-31
# 197     NG_0198  Business_198  Kaduna    Agriculture  2021-11-29
# 198     NG_0199  Business_199     Oyo    Agriculture  2022-11-08
# 199     NG_0200  Business_200  Rivers         Retail  2020-06-25
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                   417741               406718          8        False
# 1                   696804               256593         10         True
# 2                   520713                87719         11        False
# 3                   553527               389310          7        False
# 4                   231537               -11869         10         True
# ..                     ...                  ...        ...          ...
# 195                 611128               415487          8         True
# 196                 916895               349547          7        False
# 197                 778180               430501          8        False
# 198                  98486                78788          4        False
# 199                 713491               339290         10        False
#
#      accepts_mobile_money  monthly_profit_naira  profit_margin_percent
# 0                    True                 11023                   2.64
# 1                   False                440211                  63.18
# 2                    True                432994                  83.15
# 3                    True                164217                  29.67
# 4                   False                243406                 105.13
# ..                    ...                   ...                    ...
# 195                 False                195641                  32.01
# 196                  True                567348                  61.88
# 197                  True                347679                  44.68
# 198                  True                 19698                  20.00
# 199                 False                374201                  52.45
#
# [200 rows x 12 columns]

# %%
# 2. Calculate revenue per employee
df_nigeria['revenue_per_employee'] = round(df_nigeria['monthly_revenue_naira'] / df_nigeria['employees'],2)
df_nigeria.head()
# Out:
#   business_id business_name   state  business_type  start_date  \
# 0     NG_0001    Business_1   Benue         Retail  2023-02-01
# 1     NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2     NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3     NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4     NG_0005    Business_5  Rivers     Technology  2022-11-28
#
#    monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                 417741               406718          8        False
# 1                 696804               256593         10         True
# 2                 520713                87719         11        False
# 3                 553527               389310          7        False
# 4                 231537               -11869         10         True
#
#    accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 0                  True                 11023                   2.64
# 1                 False                440211                  63.18
# 2                  True                432994                  83.15
# 3                  True                164217                  29.67
# 4                 False                243406                 105.13
#
#    revenue_per_employee
# 0              52217.62
# 1              69680.40
# 2              47337.55
# 3              79075.29
# 4              23153.70

# %%
# 3. Create business age in years
current_date = pd.Timestamp('2024-10-28')
df_nigeria['business_age_years'] = round  ((current_date  - pd.to_datetime(df_nigeria['start_date'])).dt.days / 365 , 2)
df_nigeria.sample(5)
# Out:
#     business_id business_name   state business_type  start_date  \
# 153     NG_0154  Business_154  Rivers      Services  2021-12-27
# 134     NG_0135  Business_135   Benue   Agriculture  2020-06-08
# 76      NG_0077   Business_77  Kaduna   Agriculture  2021-05-27
# 34      NG_0035   Business_35     Imo        Retail  2023-09-27
# 172     NG_0173  Business_173  Rivers    Technology  2022-01-30
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 153                 239679                13311          4        False
# 134                 270389               216311          6        False
# 76                  836936               555873          6        False
# 34                  182707                89967          5         True
# 172                 538418               377069          7        False
#
#      accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 153                  True                226368                  94.45
# 134                  True                 54078                  20.00
# 76                  False                281063                  33.58
# 34                   True                 92740                  50.76
# 172                  True                161349                  29.97
#
#      revenue_per_employee  business_age_years
# 153              59919.75                2.84
# 134              45064.83                4.39
# 76              139489.33                3.42
# 34               36541.40                1.09
# 172              76916.86                2.75

# %%
# 4. Create size categories based on employees
def categorize_business_size(employees):
    if employees <= 5:
        return 'Micro'
    elif employees <= 20:
        return 'Small'
    elif employees <= 50:
        return 'Medium'
    else:
        return 'Large'

df_nigeria['business_size'] = df_nigeria['employees'].apply(categorize_business_size)
df_nigeria.head(10)
# Out:
#   business_id business_name    state  business_type  start_date  \
# 0     NG_0001    Business_1    Benue         Retail  2023-02-01
# 1     NG_0002    Business_2   Kaduna  Manufacturing  2023-11-17
# 2     NG_0003    Business_3      Oyo     Technology  2020-09-02
# 3     NG_0004    Business_4    Benue  Manufacturing  2023-04-14
# 4     NG_0005    Business_5   Rivers     Technology  2022-11-28
# 5     NG_0006    Business_6  Anambra     Technology  2022-01-28
# 6     NG_0007    Business_7      Oyo       Services  2021-06-21
# 7     NG_0008    Business_8      Oyo     Technology  2022-07-09
# 8     NG_0009    Business_9    Benue  Manufacturing  2021-02-11
# 9     NG_0010   Business_10     Kano     Technology  2021-06-08
#
#    monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                 417741               406718          8        False
# 1                 696804               256593         10         True
# 2                 520713                87719         11        False
# 3                 553527               389310          7        False
# 4                 231537               -11869         10         True
# 5                -172819              -138255          5        False
# 6                 724708               207436         12        False
# 7                 928641               111173         11        False
# 8                 431482               345185          2         True
# 9                 549862               293803          3         True
#
#    accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 0                  True                 11023                   2.64
# 1                 False                440211                  63.18
# 2                  True                432994                  83.15
# 3                  True                164217                  29.67
# 4                 False                243406                 105.13
# 5                 False                -34564                  20.00
# 6                  True                517272                  71.38
# 7                 False                817468                  88.03
# 8                 False                 86297                  20.00
# 9                 False                256059                  46.57
#
#    revenue_per_employee  business_age_years business_size
# 0              52217.62                1.74         Small
# 1              69680.40                0.95         Small
# 2              47337.55                4.16         Small
# 3              79075.29                1.54         Small
# 4              23153.70                1.92         Small
# 5             -34563.80                2.75         Micro
# 6              60392.33                3.36         Small
# 7              84421.91                2.31         Small
# 8             215741.00                3.71         Micro
# 9             183287.33                3.39         Micro

# %%
# 5. Create digital adoption score
df_nigeria['digital_score'] = (df_nigeria['has_website'].astype(int) + 
                              df_nigeria['accepts_mobile_money'].astype(int))

df_nigeria.head(5)
# Out:
#   business_id business_name   state  business_type  start_date  \
# 0     NG_0001    Business_1   Benue         Retail  2023-02-01
# 1     NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2     NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3     NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4     NG_0005    Business_5  Rivers     Technology  2022-11-28
#
#    monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                 417741               406718          8        False
# 1                 696804               256593         10         True
# 2                 520713                87719         11        False
# 3                 553527               389310          7        False
# 4                 231537               -11869         10         True
#
#    accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 0                  True                 11023                   2.64
# 1                 False                440211                  63.18
# 2                  True                432994                  83.15
# 3                  True                164217                  29.67
# 4                 False                243406                 105.13
#
#    revenue_per_employee  business_age_years business_size  digital_score
# 0              52217.62                1.74         Small              1
# 1              69680.40                0.95         Small              1
# 2              47337.55                4.16         Small              1
# 3              79075.29                1.54         Small              1
# 4              23153.70                1.92         Small              1

# %%
# Display sample of new features
df_nigeria[['business_name', 'monthly_profit_naira', 'profit_margin_percent', "business_age_years",
           'business_size', 'digital_score']].head(10)
# Out:
#   business_name  monthly_profit_naira  profit_margin_percent  \
# 0    Business_1                 11023                   2.64
# 1    Business_2                440211                  63.18
# 2    Business_3                432994                  83.15
# 3    Business_4                164217                  29.67
# 4    Business_5                243406                 105.13
# 5    Business_6                -34564                  20.00
# 6    Business_7                517272                  71.38
# 7    Business_8                817468                  88.03
# 8    Business_9                 86297                  20.00
# 9   Business_10                256059                  46.57
#
#    business_age_years business_size  digital_score
# 0                1.74         Small              1
# 1                0.95         Small              1
# 2                4.16         Small              1
# 3                1.54         Small              1
# 4                1.92         Small              1
# 5                2.75         Micro              0
# 6                3.36         Small              1
# 7                2.31         Small              0
# 8                3.71         Micro              1
# 9                3.39         Micro              1

# %% [markdown]
# ## 2. String Operations and Text Processing
#
# Let's work with text data to extract meaningful information:

# %%
df_nigeria
# Out:
#     business_id business_name   state  business_type  start_date  \
# 0       NG_0001    Business_1   Benue         Retail  2023-02-01
# 1       NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2       NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3       NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4       NG_0005    Business_5  Rivers     Technology  2022-11-28
# ..          ...           ...     ...            ...         ...
# 195     NG_0196  Business_196    Kano       Services  2023-09-27
# 196     NG_0197  Business_197    Kano    Agriculture  2021-01-31
# 197     NG_0198  Business_198  Kaduna    Agriculture  2021-11-29
# 198     NG_0199  Business_199     Oyo    Agriculture  2022-11-08
# 199     NG_0200  Business_200  Rivers         Retail  2020-06-25
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                   417741               406718          8        False
# 1                   696804               256593         10         True
# 2                   520713                87719         11        False
# 3                   553527               389310          7        False
# 4                   231537               -11869         10         True
# ..                     ...                  ...        ...          ...
# 195                 611128               415487          8         True
# 196                 916895               349547          7        False
# 197                 778180               430501          8        False
# 198                  98486                78788          4        False
# 199                 713491               339290         10        False
#
#      accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 0                    True                 11023                   2.64
# 1                   False                440211                  63.18
# 2                    True                432994                  83.15
# 3                    True                164217                  29.67
# 4                   False                243406                 105.13
# ..                    ...                   ...                    ...
# 195                 False                195641                  32.01
# 196                  True                567348                  61.88
# 197                  True                347679                  44.68
# 198                  True                 19698                  20.00
# 199                 False                374201                  52.45
#
#      revenue_per_employee  business_age_years business_size  digital_score
# 0                52217.62                1.74         Small              1
# 1                69680.40                0.95         Small              1
# 2                47337.55                4.16         Small              1
# 3                79075.29                1.54         Small              1
# 4                23153.70                1.92         Small              1
# ..                    ...                 ...           ...            ...
# 195              76391.00                1.09         Small              1
# 196             130985.00                3.74         Small              1
# 197              97272.50                2.92         Small              1
# 198              24621.50                1.97         Micro              1
# 199              71349.10                4.35         Small              0
#
# [200 rows x 16 columns]

# %%
df_nigeria_sample =df_nigeria.head(20)

df_nigeria_sample
# Out:
#    business_id business_name    state  business_type  start_date  \
# 0      NG_0001    Business_1    Benue         Retail  2023-02-01
# 1      NG_0002    Business_2   Kaduna  Manufacturing  2023-11-17
# 2      NG_0003    Business_3      Oyo     Technology  2020-09-02
# 3      NG_0004    Business_4    Benue  Manufacturing  2023-04-14
# 4      NG_0005    Business_5   Rivers     Technology  2022-11-28
# 5      NG_0006    Business_6  Anambra     Technology  2022-01-28
# 6      NG_0007    Business_7      Oyo       Services  2021-06-21
# 7      NG_0008    Business_8      Oyo     Technology  2022-07-09
# 8      NG_0009    Business_9    Benue  Manufacturing  2021-02-11
# 9      NG_0010   Business_10     Kano     Technology  2021-06-08
# 10     NG_0011   Business_11   Rivers       Services  2022-04-07
# 11     NG_0012   Business_12    Benue       Services  2022-06-21
# 12     NG_0013   Business_13   Rivers  Manufacturing  2020-02-05
# 13     NG_0014   Business_14   Rivers    Agriculture  2021-11-15
# 14     NG_0015   Business_15  Anambra    Agriculture  2020-01-20
# 15     NG_0016   Business_16      Oyo     Technology  2020-11-16
# 16     NG_0017   Business_17   Kaduna         Retail  2021-05-26
# 17     NG_0018   Business_18  Anambra     Technology  2021-02-03
# 18     NG_0019   Business_19  Anambra  Manufacturing  2021-10-15
# 19     NG_0020   Business_20   Rivers  Manufacturing  2022-08-29
#
#     monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                  417741               406718          8        False
# 1                  696804               256593         10         True
# 2                  520713                87719         11        False
# 3                  553527               389310          7        False
# 4                  231537               -11869         10         True
# 5                 -172819              -138255          5        False
# 6                  724708               207436         12        False
# 7                  928641               111173         11        False
# 8                  431482               345185          2         True
# 9                  549862               293803          3         True
# 10                 564903               326094         16        False
# 11                 835058               436180          7        False
# 12                 677796               298681          6        False
# 13                 599212               367711         13        False
# 14                 511114               422377          8         True
# 15                 512046               385013          4        False
# 16                 212107               169685          2         True
# 17                 423302               338641          8        False
# 18                 677240               486295          8        False
# 19                 453259               287135         12        False
#
#     accepts_mobile_money  monthly_profit_naira  profit_margin_percent  \
# 0                   True                 11023                   2.64
# 1                  False                440211                  63.18
# 2                   True                432994                  83.15
# 3                   True                164217                  29.67
# 4                  False                243406                 105.13
# 5                  False                -34564                  20.00
# 6                   True                517272                  71.38
# 7                  False                817468                  88.03
# 8                  False                 86297                  20.00
# 9                  False                256059                  46.57
# 10                  True                238809                  42.27
# 11                  True                398878                  47.77
# 12                  True                379115                  55.93
# 13                  True                231501                  38.63
# 14                  True                 88737                  17.36
# 15                  True                127033                  24.81
# 16                 False                 42422                  20.00
# 17                  True                 84661                  20.00
# 18                  True                190945                  28.19
# 19                 False                166124                  36.65
#
#     revenue_per_employee  business_age_years business_size  digital_score
# 0               52217.62                1.74         Small              1
# 1               69680.40                0.95         Small              1
# 2               47337.55                4.16         Small              1
# 3               79075.29                1.54         Small              1
# 4               23153.70                1.92         Small              1
# 5              -34563.80                2.75         Micro              0
# 6               60392.33                3.36         Small              1
# 7               84421.91                2.31         Small              0
# 8              215741.00                3.71         Micro              1
# 9              183287.33                3.39         Micro              1
# 10              35306.44                2.56         Small              1
# 11             119294.00                2.36         Small              1
# 12             112966.00                4.73         Small              1
# 13              46093.23                2.95         Small              1
# 14              63889.25                4.78         Small              2
# 15             128011.50                3.95         Micro              1
# 16             106053.50                3.43         Micro              1
# 17              52912.75                3.73         Small              1
# 18              84655.00                3.04         Small              1
# 19              37771.58                2.17         Small              0

# %%
# Create more realistic business names with African context
african_business_names = [
    'Lagos-Adunni Fashion House/Union', 'Kano-Groundnut/Cooperative Ltd',
    'Rivers-Palm Oil Processing/Association', 'Kaduna-Textile Manufacturing/Services Ltd',
    'Oyo-Agro Pastoral/Services Limited', 'Imo-Cassava Farmers/Union',
    'Benue-Yam Gem/Trading Company', 'Anambra-Tech Solutions/Association',
    'Lagos-Digital Marketing Hub/Society', 'Kano-Leather Works/Services Ltd',
    'Port Harcourt-Fish Market/Union', 'Abuja-Movie Consulting/Limited Services',
    'Ibadan-Food Processing/Cooperative', 'Enugu-Coal Trading Co/Association',
    'Calabar-Tourism Services/Union', 'Abuja-Mining Equipments/Association',
    'Maiduguri-Livestock Market/Trading Partners Ltd', 'Sokoto-Onion Farmers/Services Limited',
    'Benin-Rubber Plantation/Cooperative', 'Warri-Oil Refining/Services Ltd'
]

# Assign realistic names to first 20 businesses
df_nigeria_sample.loc[:19, 'business_name'] = african_business_names

df_nigeria_sample
# Out:
#    business_id                                    business_name  \
# 0      NG_0001                 Lagos-Adunni Fashion House/Union
# 1      NG_0002                   Kano-Groundnut/Cooperative Ltd
# 2      NG_0003           Rivers-Palm Oil Processing/Association
# 3      NG_0004        Kaduna-Textile Manufacturing/Services Ltd
# 4      NG_0005               Oyo-Agro Pastoral/Services Limited
# 5      NG_0006                        Imo-Cassava Farmers/Union
# 6      NG_0007                    Benue-Yam Gem/Trading Company
# 7      NG_0008               Anambra-Tech Solutions/Association
# 8      NG_0009              Lagos-Digital Marketing Hub/Society
# 9      NG_0010                  Kano-Leather Works/Services Ltd
# 10     NG_0011                  Port Harcourt-Fish Market/Union
# 11     NG_0012          Abuja-Movie Consulting/Limited Services
# 12     NG_0013               Ibadan-Food Processing/Cooperative
# 13     NG_0014                Enugu-Coal Trading Co/Association
# 14     NG_0015                   Calabar-Tourism Services/Union
# 15     NG_0016              Abuja-Mining Equipments/Association
# 16     NG_0017  Maiduguri-Livestock Market/Trading Partners Ltd
# 17     NG_0018            Sokoto-Onion Farmers/Services Limited
# 18     NG_0019              Benin-Rubber Plantation/Cooperative
# 19     NG_0020                  Warri-Oil Refining/Services Ltd
#
#             state  business_type  start_date  monthly_revenue_naira  \
# 0           Lagos         Retail  2023-02-01                 417741
# 1            Kano  Manufacturing  2023-11-17                 696804
# 2          Rivers     Technology  2020-09-02                 520713
# 3          Kaduna  Manufacturing  2023-04-14                 553527
# 4             Oyo     Technology  2022-11-28                 231537
# 5             Imo     Technology  2022-01-28                -172819
# 6           Benin       Services  2021-06-21                 724708
# 7         Anambra     Technology  2022-07-09                 928641
# 8           Lagos  Manufacturing  2021-02-11                 431482
# 9            Kano     Technology  2021-06-08                 549862
# 10  Port Harcourt       Services  2022-04-07                 564903
# 11          Abuja       Services  2022-06-21                 835058
# 12         Ibadan  Manufacturing  2020-02-05                 677796
# 13          Enugu    Agriculture  2021-11-15                 599212
# 14        Calabar    Agriculture  2020-01-20                 511114
# 15          Abuja     Technology  2020-11-16                 512046
# 16      Maiduguri         Retail  2021-05-26                 212107
# 17         Sokoto     Technology  2021-02-03                 423302
# 18          Benin  Manufacturing  2021-10-15                 677240
# 19          Warri  Manufacturing  2022-08-29                 453259
#
#     monthly_costs_naira  employees  has_website  accepts_mobile_money  \
# 0                406718          8        False                  True
# 1                256593         10         True                 False
# 2                 87719         11        False                  True
# 3                389310          7        False                  True
# 4                -11869         10         True                 False
# 5               -138255          5        False                 False
# 6                207436         12        False                  True
# 7                111173         11        False                 False
# 8                345185          2         True                 False
# 9                293803          3         True                 False
# 10               326094         16        False                  True
# 11               436180          7        False                  True
# 12               298681          6        False                  True
# 13               367711         13        False                  True
# 14               422377          8         True                  True
# 15               385013          4        False                  True
# 16               169685          2         True                 False
# 17               338641          8        False                  True
# 18               486295          8        False                  True
# 19               287135         12        False                 False
#
#     monthly_profit_naira  profit_margin_percent  revenue_per_employee  \
# 0                  11023                   2.64              52217.62
# 1                 440211                  63.18              69680.40
# 2                 432994                  83.15              47337.55
# 3                 164217                  29.67              79075.29
# 4                 243406                 105.13              23153.70
# 5                 -34564                  20.00             -34563.80
# 6                 517272                  71.38              60392.33
# 7                 817468                  88.03              84421.91
# 8                  86297                  20.00             215741.00
# 9                 256059                  46.57             183287.33
# 10                238809                  42.27              35306.44
# 11                398878                  47.77             119294.00
# 12                379115                  55.93             112966.00
# 13                231501                  38.63              46093.23
# 14                 88737                  17.36              63889.25
# 15                127033                  24.81             128011.50
# 16                 42422                  20.00             106053.50
# 17                 84661                  20.00              52912.75
# 18                190945                  28.19              84655.00
# 19                166124                  36.65              37771.58
#
#     business_age_years business_size  digital_score    business_structure  \
# 0                 1.74         Small              1                 Union
# 1                 0.95         Small              1       Cooperative Ltd
# 2                 4.16         Small              1           Association
# 3                 1.54         Small              1          Services Ltd
# 4                 1.92         Small              1      Services Limited
# 5                 2.75         Micro              0                 Union
# 6                 3.36         Small              1       Trading Company
# 7                 2.31         Small              0           Association
# 8                 3.71         Micro              1               Society
# 9                 3.39         Micro              1          Services Ltd
# 10                2.56         Small              1                 Union
# 11                2.36         Small              1      Limited Services
# 12                4.73         Small              1           Cooperative
# 13                2.95         Small              1           Association
# 14                4.78         Small              2                 Union
# 15                3.95         Micro              1           Association
# 16                3.43         Micro              1  Trading Partners Ltd
# 17                3.73         Small              1      Services Limited
# 18                3.04         Small              1           Cooperative
# 19                2.17         Small              0          Services Ltd
#
#     is_agricultural  is_tech_related  is_manufacturing
# 0             False            False             False
# 1              True            False             False
# 2              True            False              True
# 3             False            False              True
# 4              True            False             False
# 5              True            False             False
# 6              True            False             False
# 7             False             True             False
# 8             False             True             False
# 9             False            False              True
# 10            False            False             False
# 11            False            False             False
# 12            False            False              True
# 13            False            False             False
# 14            False            False             False
# 15            False            False              True
# 16             True            False             False
# 17             True            False             False
# 18            False            False             False
# 19            False            False             False

# %%
# 1. Extract state from business name
df_nigeria_sample['state'] = df_nigeria_sample['business_name'].str.split("-").str[0]
df_nigeria_sample['state']
# Out:
# 0             Lagos
# 1              Kano
# 2            Rivers
# 3            Kaduna
# 4               Oyo
# 5               Imo
# 6             Benue
# 7           Anambra
# 8             Lagos
# 9              Kano
# 10    Port Harcourt
# 11            Abuja
# 12           Ibadan
# 13            Enugu
# 14          Calabar
# 15            Abuja
# 16        Maiduguri
# 17           Sokoto
# 18            Benin
# 19            Warri
# Name: state, dtype: object

# %%
# 4. Extract business structure (Ltd, Co, etc.)
df_nigeria_sample['business_structure'] = df_nigeria_sample['business_name'].str.split("/").str[-1]
df_nigeria_sample['business_structure']
# Out:
# 0                    Union
# 1          Cooperative Ltd
# 2              Association
# 3             Services Ltd
# 4         Services Limited
# 5                    Union
# 6          Trading Company
# 7              Association
# 8                  Society
# 9             Services Ltd
# 10                   Union
# 11        Limited Services
# 12             Cooperative
# 13             Association
# 14                   Union
# 15             Association
# 16    Trading Partners Ltd
# 17        Services Limited
# 18             Cooperative
# 19            Services Ltd
# Name: business_structure, dtype: object

# %%
# 2. Check if business name contains certain keywords
df_nigeria_sample['is_agricultural'] = df_nigeria_sample['business_name'].str.contains('Agro|Farm|Cassava|Groundnut|Yam|Palm|Onion|Livestock', case=False, na=False)
df_nigeria_sample['is_tech_related'] = df_nigeria_sample['business_name'].str.contains('Tech|Digital|Solutions|Hub', case=False, na=False)
df_nigeria_sample['is_manufacturing'] = df_nigeria_sample['business_name'].str.contains('Manufacturing|Processing|Works|Equipment', case=False, na=False)
df_nigeria_sample
#
# Out:
#    business_id                                    business_name  \
# 0      NG_0001                 Lagos-Adunni Fashion House/Union
# 1      NG_0002                   Kano-Groundnut/Cooperative Ltd
# 2      NG_0003           Rivers-Palm Oil Processing/Association
# 3      NG_0004        Kaduna-Textile Manufacturing/Services Ltd
# 4      NG_0005               Oyo-Agro Pastoral/Services Limited
# 5      NG_0006                        Imo-Cassava Farmers/Union
# 6      NG_0007                    Benue-Yam Gem/Trading Company
# 7      NG_0008               Anambra-Tech Solutions/Association
# 8      NG_0009              Lagos-Digital Marketing Hub/Society
# 9      NG_0010                  Kano-Leather Works/Services Ltd
# 10     NG_0011                  Port Harcourt-Fish Market/Union
# 11     NG_0012          Abuja-Movie Consulting/Limited Services
# 12     NG_0013               Ibadan-Food Processing/Cooperative
# 13     NG_0014                Enugu-Coal Trading Co/Association
# 14     NG_0015                   Calabar-Tourism Services/Union
# 15     NG_0016              Abuja-Mining Equipments/Association
# 16     NG_0017  Maiduguri-Livestock Market/Trading Partners Ltd
# 17     NG_0018            Sokoto-Onion Farmers/Services Limited
# 18     NG_0019              Benin-Rubber Plantation/Cooperative
# 19     NG_0020                  Warri-Oil Refining/Services Ltd
#
#             state  business_type  start_date  monthly_revenue_naira  \
# 0           Lagos         Retail  2023-02-01                 417741
# 1            Kano  Manufacturing  2023-11-17                 696804
# 2          Rivers     Technology  2020-09-02                 520713
# 3          Kaduna  Manufacturing  2023-04-14                 553527
# 4             Oyo     Technology  2022-11-28                 231537
# 5             Imo     Technology  2022-01-28                -172819
# 6           Benue       Services  2021-06-21                 724708
# 7         Anambra     Technology  2022-07-09                 928641
# 8           Lagos  Manufacturing  2021-02-11                 431482
# 9            Kano     Technology  2021-06-08                 549862
# 10  Port Harcourt       Services  2022-04-07                 564903
# 11          Abuja       Services  2022-06-21                 835058
# 12         Ibadan  Manufacturing  2020-02-05                 677796
# 13          Enugu    Agriculture  2021-11-15                 599212
# 14        Calabar    Agriculture  2020-01-20                 511114
# 15          Abuja     Technology  2020-11-16                 512046
# 16      Maiduguri         Retail  2021-05-26                 212107
# 17         Sokoto     Technology  2021-02-03                 423302
# 18          Benin  Manufacturing  2021-10-15                 677240
# 19          Warri  Manufacturing  2022-08-29                 453259
#
#     monthly_costs_naira  employees  has_website  accepts_mobile_money  \
# 0                406718          8        False                  True
# 1                256593         10         True                 False
# 2                 87719         11        False                  True
# 3                389310          7        False                  True
# 4                -11869         10         True                 False
# 5               -138255          5        False                 False
# 6                207436         12        False                  True
# 7                111173         11        False                 False
# 8                345185          2         True                 False
# 9                293803          3         True                 False
# 10               326094         16        False                  True
# 11               436180          7        False                  True
# 12               298681          6        False                  True
# 13               367711         13        False                  True
# 14               422377          8         True                  True
# 15               385013          4        False                  True
# 16               169685          2         True                 False
# 17               338641          8        False                  True
# 18               486295          8        False                  True
# 19               287135         12        False                 False
#
#     monthly_profit_naira  profit_margin_percent  revenue_per_employee  \
# 0                  11023                   2.64              52217.62
# 1                 440211                  63.18              69680.40
# 2                 432994                  83.15              47337.55
# 3                 164217                  29.67              79075.29
# 4                 243406                 105.13              23153.70
# 5                 -34564                  20.00             -34563.80
# 6                 517272                  71.38              60392.33
# 7                 817468                  88.03              84421.91
# 8                  86297                  20.00             215741.00
# 9                 256059                  46.57             183287.33
# 10                238809                  42.27              35306.44
# 11                398878                  47.77             119294.00
# 12                379115                  55.93             112966.00
# 13                231501                  38.63              46093.23
# 14                 88737                  17.36              63889.25
# 15                127033                  24.81             128011.50
# 16                 42422                  20.00             106053.50
# 17                 84661                  20.00              52912.75
# 18                190945                  28.19              84655.00
# 19                166124                  36.65              37771.58
#
#     business_age_years business_size  digital_score    business_structure  \
# 0                 1.74         Small              1                 Union
# 1                 0.95         Small              1       Cooperative Ltd
# 2                 4.16         Small              1           Association
# 3                 1.54         Small              1          Services Ltd
# 4                 1.92         Small              1      Services Limited
# 5                 2.75         Micro              0                 Union
# 6                 3.36         Small              1       Trading Company
# 7                 2.31         Small              0           Association
# 8                 3.71         Micro              1               Society
# 9                 3.39         Micro              1          Services Ltd
# 10                2.56         Small              1                 Union
# 11                2.36         Small              1      Limited Services
# 12                4.73         Small              1           Cooperative
# 13                2.95         Small              1           Association
# 14                4.78         Small              2                 Union
# 15                3.95         Micro              1           Association
# 16                3.43         Micro              1  Trading Partners Ltd
# 17                3.73         Small              1      Services Limited
# 18                3.04         Small              1           Cooperative
# 19                2.17         Small              0          Services Ltd
#
#     is_agricultural  is_tech_related  is_manufacturing
# 0             False            False             False
# 1              True            False             False
# 2              True            False              True
# 3             False            False              True
# 4              True            False             False
# 5              True            False             False
# 6              True            False             False
# 7             False             True             False
# 8             False             True             False
# 9             False            False              True
# 10            False            False             False
# 11            False            False             False
# 12            False            False              True
# 13            False            False             False
# 14            False            False             False
# 15            False            False              True
# 16             True            False             False
# 17             True            False             False
# 18            False            False             False
# 19            False            False             False

# %%
print(f"\nSample of text-derived features:")
df_nigeria_sample[['business_name', 'state', 'is_agricultural', 
           'is_tech_related', 'business_structure']].head(10)
# Out:
# Sample of text-derived features:
#                                business_name    state  is_agricultural  \
# 0           Lagos-Adunni Fashion House/Union    Lagos            False
# 1             Kano-Groundnut/Cooperative Ltd     Kano             True
# 2     Rivers-Palm Oil Processing/Association   Rivers             True
# 3  Kaduna-Textile Manufacturing/Services Ltd   Kaduna            False
# 4         Oyo-Agro Pastoral/Services Limited      Oyo             True
# 5                  Imo-Cassava Farmers/Union      Imo             True
# 6              Benue-Yam Gem/Trading Company    Benue             True
# 7         Anambra-Tech Solutions/Association  Anambra            False
# 8        Lagos-Digital Marketing Hub/Society    Lagos            False
# 9            Kano-Leather Works/Services Ltd     Kano            False
#
#    is_tech_related business_structure
# 0            False              Union
# 1            False    Cooperative Ltd
# 2            False        Association
# 3            False       Services Ltd
# 4            False   Services Limited
# 5            False              Union
# 6            False    Trading Company
# 7             True        Association
# 8             True            Society
# 9            False       Services Ltd

# %% [markdown]
# ## 3. Categorical Data Handling
#
# Let's work with categorical variables and create meaningful groupings:

# %%
# 1. Create regional groupings
def assign_region(state):
    north = ['Kano', 'Kaduna', 'Benue']
    south_west = ['Lagos', 'Oyo']
    south_east = ['Imo', 'Anambra']
    south_south = ['Rivers']
    
    if state in north:
        return 'North'
    elif state in south_west:
        return 'South-West'
    elif state in south_east:
        return 'South-East'
    elif state in south_south:
        return 'South-South'
    else:
        return 'Other'

df_nigeria_sample['region'] = df_nigeria_sample['state'].apply(assign_region)
df_nigeria_sample['region']
# Out:
# 0      South-West
# 1           North
# 2     South-South
# 3           North
# 4      South-West
# 5      South-East
# 6           North
# 7      South-East
# 8      South-West
# 9           North
# 10          Other
# 11          Other
# 12          Other
# 13          Other
# 14          Other
# 15          Other
# 16          Other
# 17          Other
# 18          Other
# 19          Other
# Name: region, dtype: object

# %%
pd.Series.quantile?
# Out:
# Signature:
# pd.Series.quantile(
#     self,
#     q: 'float | Sequence[float] | AnyArrayLike' = 0.5,
#     interpolation: 'QuantileInterpolation' = 'linear',
# ) -> 'float | Series'
# Docstring:
# Return value at the given quantile.
#
# Parameters
# ----------
# q : float or array-like, default 0.5 (50% quantile)
#     The quantile(s) to compute, which can lie in range: 0 <= q <= 1.
# interpolation : {'linear', 'lower', 'higher', 'midpoint', 'nearest'}
#     This optional parameter specifies the interpolation method to use,
#     when the desired quantile lies between two data points `i` and `j`:
#
#         * linear: `i + (j - i) * (x-i)/(j-i)`, where `(x-i)/(j-i)` is
#           the fractional part of the index surrounded by `i > j`.
#         * lower: `i`.
#         * higher: `j`.
#         * nearest: `i` or `j` whichever is nearest.
#         * midpoint: (`i` + `j`) / 2.
#
# Returns
# -------
# float or Series
#     If ``q`` is an array, a Series will be returned where the
#     index is ``q`` and the values are the quantiles, otherwise
#     a float will be returned.
#
# See Also
# --------
# core.window.Rolling.quantile : Calculate the rolling quantile.
# numpy.percentile : Returns the q-th percentile(s) of the array elements.
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3, 4])
# >>> s.quantile(.5)
# 2.5
# >>> s.quantile([.25, .5, .75])
# 0.25    1.75
# 0.50    2.50
# 0.75    3.25
# dtype: float64
# File:      /opt/anaconda3/envs/postkv_env/lib/python3.13/site-packages/pandas/core/series.py
# Type:      function

# %%
# 2. Create performance categories
profit_quartiles = df_nigeria_sample['profit_margin_percent'].quantile([0.25, 0.5, 0.75])
profit_quartiles
# Out:
# 0.25    20.0000
# 0.50    37.6400
# 0.75    57.7425
# Name: profit_margin_percent, dtype: float64

# %%
def categorize_performance(profit_margin):
    if profit_margin < profit_quartiles[0.25]:
        return 'Low Performer'
    elif profit_margin < profit_quartiles[0.5]:
        return 'Average Performer'
    elif profit_margin < profit_quartiles[0.75]:
        return 'Good Performer'
    else:
        return 'Top Performer'

df_nigeria_sample['performance_category'] = df_nigeria_sample['profit_margin_percent'].apply(categorize_performance)
df_nigeria_sample
# Out:
#    business_id                                    business_name  \
# 0      NG_0001                 Lagos-Adunni Fashion House/Union
# 1      NG_0002                   Kano-Groundnut/Cooperative Ltd
# 2      NG_0003           Rivers-Palm Oil Processing/Association
# 3      NG_0004        Kaduna-Textile Manufacturing/Services Ltd
# 4      NG_0005               Oyo-Agro Pastoral/Services Limited
# 5      NG_0006                        Imo-Cassava Farmers/Union
# 6      NG_0007                    Benue-Yam Gem/Trading Company
# 7      NG_0008               Anambra-Tech Solutions/Association
# 8      NG_0009              Lagos-Digital Marketing Hub/Society
# 9      NG_0010                  Kano-Leather Works/Services Ltd
# 10     NG_0011                  Port Harcourt-Fish Market/Union
# 11     NG_0012          Abuja-Movie Consulting/Limited Services
# 12     NG_0013               Ibadan-Food Processing/Cooperative
# 13     NG_0014                Enugu-Coal Trading Co/Association
# 14     NG_0015                   Calabar-Tourism Services/Union
# 15     NG_0016              Abuja-Mining Equipments/Association
# 16     NG_0017  Maiduguri-Livestock Market/Trading Partners Ltd
# 17     NG_0018            Sokoto-Onion Farmers/Services Limited
# 18     NG_0019              Benin-Rubber Plantation/Cooperative
# 19     NG_0020                  Warri-Oil Refining/Services Ltd
#
#             state  business_type  start_date  monthly_revenue_naira  \
# 0           Lagos         Retail  2023-02-01                 417741
# 1            Kano  Manufacturing  2023-11-17                 696804
# 2          Rivers     Technology  2020-09-02                 520713
# 3          Kaduna  Manufacturing  2023-04-14                 553527
# 4             Oyo     Technology  2022-11-28                 231537
# 5             Imo     Technology  2022-01-28                -172819
# 6           Benue       Services  2021-06-21                 724708
# 7         Anambra     Technology  2022-07-09                 928641
# 8           Lagos  Manufacturing  2021-02-11                 431482
# 9            Kano     Technology  2021-06-08                 549862
# 10  Port Harcourt       Services  2022-04-07                 564903
# 11          Abuja       Services  2022-06-21                 835058
# 12         Ibadan  Manufacturing  2020-02-05                 677796
# 13          Enugu    Agriculture  2021-11-15                 599212
# 14        Calabar    Agriculture  2020-01-20                 511114
# 15          Abuja     Technology  2020-11-16                 512046
# 16      Maiduguri         Retail  2021-05-26                 212107
# 17         Sokoto     Technology  2021-02-03                 423302
# 18          Benin  Manufacturing  2021-10-15                 677240
# 19          Warri  Manufacturing  2022-08-29                 453259
#
#     monthly_costs_naira  employees  has_website  accepts_mobile_money  \
# 0                406718          8        False                  True
# 1                256593         10         True                 False
# 2                 87719         11        False                  True
# 3                389310          7        False                  True
# 4                -11869         10         True                 False
# 5               -138255          5        False                 False
# 6                207436         12        False                  True
# 7                111173         11        False                 False
# 8                345185          2         True                 False
# 9                293803          3         True                 False
# 10               326094         16        False                  True
# 11               436180          7        False                  True
# 12               298681          6        False                  True
# 13               367711         13        False                  True
# 14               422377          8         True                  True
# 15               385013          4        False                  True
# 16               169685          2         True                 False
# 17               338641          8        False                  True
# 18               486295          8        False                  True
# 19               287135         12        False                 False
#
#     monthly_profit_naira  profit_margin_percent  revenue_per_employee  \
# 0                  11023                   2.64              52217.62
# 1                 440211                  63.18              69680.40
# 2                 432994                  83.15              47337.55
# 3                 164217                  29.67              79075.29
# 4                 243406                 105.13              23153.70
# 5                 -34564                  20.00             -34563.80
# 6                 517272                  71.38              60392.33
# 7                 817468                  88.03              84421.91
# 8                  86297                  20.00             215741.00
# 9                 256059                  46.57             183287.33
# 10                238809                  42.27              35306.44
# 11                398878                  47.77             119294.00
# 12                379115                  55.93             112966.00
# 13                231501                  38.63              46093.23
# 14                 88737                  17.36              63889.25
# 15                127033                  24.81             128011.50
# 16                 42422                  20.00             106053.50
# 17                 84661                  20.00              52912.75
# 18                190945                  28.19              84655.00
# 19                166124                  36.65              37771.58
#
#     business_age_years business_size  digital_score    business_structure  \
# 0                 1.74         Small              1                 Union
# 1                 0.95         Small              1       Cooperative Ltd
# 2                 4.16         Small              1           Association
# 3                 1.54         Small              1          Services Ltd
# 4                 1.92         Small              1      Services Limited
# 5                 2.75         Micro              0                 Union
# 6                 3.36         Small              1       Trading Company
# 7                 2.31         Small              0           Association
# 8                 3.71         Micro              1               Society
# 9                 3.39         Micro              1          Services Ltd
# 10                2.56         Small              1                 Union
# 11                2.36         Small              1      Limited Services
# 12                4.73         Small              1           Cooperative
# 13                2.95         Small              1           Association
# 14                4.78         Small              2                 Union
# 15                3.95         Micro              1           Association
# 16                3.43         Micro              1  Trading Partners Ltd
# 17                3.73         Small              1      Services Limited
# 18                3.04         Small              1           Cooperative
# 19                2.17         Small              0          Services Ltd
#
#     is_agricultural  is_tech_related  is_manufacturing       region  \
# 0             False            False             False   South-West
# 1              True            False             False        North
# 2              True            False              True  South-South
# 3             False            False              True        North
# 4              True            False             False   South-West
# 5              True            False             False   South-East
# 6              True            False             False        North
# 7             False             True             False   South-East
# 8             False             True             False   South-West
# 9             False            False              True        North
# 10            False            False             False        Other
# 11            False            False             False        Other
# 12            False            False              True        Other
# 13            False            False             False        Other
# 14            False            False             False        Other
# 15            False            False              True        Other
# 16             True            False             False        Other
# 17             True            False             False        Other
# 18            False            False             False        Other
# 19            False            False             False        Other
#
#    performance_category
# 0         Low Performer
# 1         Top Performer
# 2         Top Performer
# 3     Average Performer
# 4         Top Performer
# 5     Average Performer
# 6         Top Performer
# 7         Top Performer
# 8     Average Performer
# 9        Good Performer
# 10       Good Performer
# 11       Good Performer
# 12       Good Performer
# 13       Good Performer
# 14        Low Performer
# 15    Average Performer
# 16    Average Performer
# 17    Average Performer
# 18    Average Performer
# 19    Average Performer

# %%
# 3. One-hot encoding for categorical variables
# Create dummy variables for business type
business_type_dummies = pd.get_dummies(df_nigeria_sample['business_type'], prefix='type')
business_type_dummies
# Out:
#     type_Agriculture  type_Manufacturing  type_Retail  type_Services  \
# 0              False               False         True          False
# 1              False                True        False          False
# 2              False               False        False          False
# 3              False                True        False          False
# 4              False               False        False          False
# 5              False               False        False          False
# 6              False               False        False           True
# 7              False               False        False          False
# 8              False                True        False          False
# 9              False               False        False          False
# 10             False               False        False           True
# 11             False               False        False           True
# 12             False                True        False          False
# 13              True               False        False          False
# 14              True               False        False          False
# 15             False               False        False          False
# 16             False               False         True          False
# 17             False               False        False          False
# 18             False                True        False          False
# 19             False                True        False          False
#
#     type_Technology
# 0             False
# 1             False
# 2              True
# 3             False
# 4              True
# 5              True
# 6             False
# 7              True
# 8             False
# 9              True
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15             True
# 16            False
# 17             True
# 18            False
# 19            False

# %%
region_dummies = pd.get_dummies(df_nigeria_sample['region'], prefix='region')
region_dummies
# Out:
#     region_North  region_Other  region_South-East  region_South-South  \
# 0          False         False              False               False
# 1           True         False              False               False
# 2          False         False              False                True
# 3           True         False              False               False
# 4          False         False              False               False
# 5          False         False               True               False
# 6           True         False              False               False
# 7          False         False               True               False
# 8          False         False              False               False
# 9           True         False              False               False
# 10         False          True              False               False
# 11         False          True              False               False
# 12         False          True              False               False
# 13         False          True              False               False
# 14         False          True              False               False
# 15         False          True              False               False
# 16         False          True              False               False
# 17         False          True              False               False
# 18         False          True              False               False
# 19         False          True              False               False
#
#     region_South-West
# 0                True
# 1               False
# 2               False
# 3               False
# 4                True
# 5               False
# 6               False
# 7               False
# 8                True
# 9               False
# 10              False
# 11              False
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17              False
# 18              False
# 19              False

# %%
# Add dummy variables to main dataframe
df_nigeria_sample = pd.concat([df_nigeria_sample, business_type_dummies, region_dummies], axis=1)
df_nigeria_sample
# Out:
#    business_id                                    business_name  \
# 0      NG_0001                 Lagos-Adunni Fashion House/Union
# 1      NG_0002                   Kano-Groundnut/Cooperative Ltd
# 2      NG_0003           Rivers-Palm Oil Processing/Association
# 3      NG_0004        Kaduna-Textile Manufacturing/Services Ltd
# 4      NG_0005               Oyo-Agro Pastoral/Services Limited
# 5      NG_0006                        Imo-Cassava Farmers/Union
# 6      NG_0007                    Benue-Yam Gem/Trading Company
# 7      NG_0008               Anambra-Tech Solutions/Association
# 8      NG_0009              Lagos-Digital Marketing Hub/Society
# 9      NG_0010                  Kano-Leather Works/Services Ltd
# 10     NG_0011                  Port Harcourt-Fish Market/Union
# 11     NG_0012          Abuja-Movie Consulting/Limited Services
# 12     NG_0013               Ibadan-Food Processing/Cooperative
# 13     NG_0014                Enugu-Coal Trading Co/Association
# 14     NG_0015                   Calabar-Tourism Services/Union
# 15     NG_0016              Abuja-Mining Equipments/Association
# 16     NG_0017  Maiduguri-Livestock Market/Trading Partners Ltd
# 17     NG_0018            Sokoto-Onion Farmers/Services Limited
# 18     NG_0019              Benin-Rubber Plantation/Cooperative
# 19     NG_0020                  Warri-Oil Refining/Services Ltd
#
#             state  business_type  start_date  monthly_revenue_naira  \
# 0           Lagos         Retail  2023-02-01                 417741
# 1            Kano  Manufacturing  2023-11-17                 696804
# 2          Rivers     Technology  2020-09-02                 520713
# 3          Kaduna  Manufacturing  2023-04-14                 553527
# 4             Oyo     Technology  2022-11-28                 231537
# 5             Imo     Technology  2022-01-28                -172819
# 6           Benue       Services  2021-06-21                 724708
# 7         Anambra     Technology  2022-07-09                 928641
# 8           Lagos  Manufacturing  2021-02-11                 431482
# 9            Kano     Technology  2021-06-08                 549862
# 10  Port Harcourt       Services  2022-04-07                 564903
# 11          Abuja       Services  2022-06-21                 835058
# 12         Ibadan  Manufacturing  2020-02-05                 677796
# 13          Enugu    Agriculture  2021-11-15                 599212
# 14        Calabar    Agriculture  2020-01-20                 511114
# 15          Abuja     Technology  2020-11-16                 512046
# 16      Maiduguri         Retail  2021-05-26                 212107
# 17         Sokoto     Technology  2021-02-03                 423302
# 18          Benin  Manufacturing  2021-10-15                 677240
# 19          Warri  Manufacturing  2022-08-29                 453259
#
#     monthly_costs_naira  employees  has_website  accepts_mobile_money  \
# 0                406718          8        False                  True
# 1                256593         10         True                 False
# 2                 87719         11        False                  True
# 3                389310          7        False                  True
# 4                -11869         10         True                 False
# 5               -138255          5        False                 False
# 6                207436         12        False                  True
# 7                111173         11        False                 False
# 8                345185          2         True                 False
# 9                293803          3         True                 False
# 10               326094         16        False                  True
# 11               436180          7        False                  True
# 12               298681          6        False                  True
# 13               367711         13        False                  True
# 14               422377          8         True                  True
# 15               385013          4        False                  True
# 16               169685          2         True                 False
# 17               338641          8        False                  True
# 18               486295          8        False                  True
# 19               287135         12        False                 False
#
#     monthly_profit_naira  profit_margin_percent  revenue_per_employee  \
# 0                  11023                   2.64              52217.62
# 1                 440211                  63.18              69680.40
# 2                 432994                  83.15              47337.55
# 3                 164217                  29.67              79075.29
# 4                 243406                 105.13              23153.70
# 5                 -34564                  20.00             -34563.80
# 6                 517272                  71.38              60392.33
# 7                 817468                  88.03              84421.91
# 8                  86297                  20.00             215741.00
# 9                 256059                  46.57             183287.33
# 10                238809                  42.27              35306.44
# 11                398878                  47.77             119294.00
# 12                379115                  55.93             112966.00
# 13                231501                  38.63              46093.23
# 14                 88737                  17.36              63889.25
# 15                127033                  24.81             128011.50
# 16                 42422                  20.00             106053.50
# 17                 84661                  20.00              52912.75
# 18                190945                  28.19              84655.00
# 19                166124                  36.65              37771.58
#
#     business_age_years business_size  digital_score    business_structure  \
# 0                 1.74         Small              1                 Union
# 1                 0.95         Small              1       Cooperative Ltd
# 2                 4.16         Small              1           Association
# 3                 1.54         Small              1          Services Ltd
# 4                 1.92         Small              1      Services Limited
# 5                 2.75         Micro              0                 Union
# 6                 3.36         Small              1       Trading Company
# 7                 2.31         Small              0           Association
# 8                 3.71         Micro              1               Society
# 9                 3.39         Micro              1          Services Ltd
# 10                2.56         Small              1                 Union
# 11                2.36         Small              1      Limited Services
# 12                4.73         Small              1           Cooperative
# 13                2.95         Small              1           Association
# 14                4.78         Small              2                 Union
# 15                3.95         Micro              1           Association
# 16                3.43         Micro              1  Trading Partners Ltd
# 17                3.73         Small              1      Services Limited
# 18                3.04         Small              1           Cooperative
# 19                2.17         Small              0          Services Ltd
#
#     is_agricultural  is_tech_related  is_manufacturing       region  \
# 0             False            False             False   South-West
# 1              True            False             False        North
# 2              True            False              True  South-South
# 3             False            False              True        North
# 4              True            False             False   South-West
# 5              True            False             False   South-East
# 6              True            False             False        North
# 7             False             True             False   South-East
# 8             False             True             False   South-West
# 9             False            False              True        North
# 10            False            False             False        Other
# 11            False            False             False        Other
# 12            False            False              True        Other
# 13            False            False             False        Other
# 14            False            False             False        Other
# 15            False            False              True        Other
# 16             True            False             False        Other
# 17             True            False             False        Other
# 18            False            False             False        Other
# 19            False            False             False        Other
#
#    performance_category  type_Agriculture  type_Manufacturing  type_Retail  \
# 0         Low Performer             False               False         True
# 1         Top Performer             False                True        False
# 2         Top Performer             False               False        False
# 3     Average Performer             False                True        False
# 4         Top Performer             False               False        False
# 5     Average Performer             False               False        False
# 6         Top Performer             False               False        False
# 7         Top Performer             False               False        False
# 8     Average Performer             False                True        False
# 9        Good Performer             False               False        False
# 10       Good Performer             False               False        False
# 11       Good Performer             False               False        False
# 12       Good Performer             False                True        False
# 13       Good Performer              True               False        False
# 14        Low Performer              True               False        False
# 15    Average Performer             False               False        False
# 16    Average Performer             False               False         True
# 17    Average Performer             False               False        False
# 18    Average Performer             False                True        False
# 19    Average Performer             False                True        False
#
#     type_Services  type_Technology  region_North  region_Other  \
# 0           False            False         False         False
# 1           False            False          True         False
# 2           False             True         False         False
# 3           False            False          True         False
# 4           False             True         False         False
# 5           False             True         False         False
# 6            True            False          True         False
# 7           False             True         False         False
# 8           False            False         False         False
# 9           False             True          True         False
# 10           True            False         False          True
# 11           True            False         False          True
# 12          False            False         False          True
# 13          False            False         False          True
# 14          False            False         False          True
# 15          False             True         False          True
# 16          False            False         False          True
# 17          False             True         False          True
# 18          False            False         False          True
# 19          False            False         False          True
#
#     region_South-East  region_South-South  region_South-West
# 0               False               False               True
# 1               False               False              False
# 2               False                True              False
# 3               False               False              False
# 4               False               False               True
# 5                True               False              False
# 6               False               False              False
# 7                True               False              False
# 8               False               False               True
# 9               False               False              False
# 10              False               False              False
# 11              False               False              False
# 12              False               False              False
# 13              False               False              False
# 14              False               False              False
# 15              False               False              False
# 16              False               False              False
# 17              False               False              False
# 18              False               False              False
# 19              False               False              False

# %%
print("Categorical data processing completed!")
print(f"\nRegion distribution:")
print(df_nigeria_sample['region'].value_counts())
print(f"\nPerformance category distribution:")
print(df_nigeria_sample['performance_category'].value_counts())
print(f"\nNew dummy columns created: {list(business_type_dummies.columns) + list(region_dummies.columns)}")
# Out:
# Categorical data processing completed!
#
# Region distribution:
# region
# Other          10
# North           4
# South-West      3
# South-East      2
# South-South     1
# Name: count, dtype: int64
#
# Performance category distribution:
# performance_category
# Average Performer    8
# Top Performer        5
# Good Performer       5
# Low Performer        2
# Name: count, dtype: int64
#
# New dummy columns created: ['type_Agriculture', 'type_Manufacturing', 'type_Retail', 'type_Services', 'type_Technology', 'region_North', 'region_Other', 'region_South-East', 'region_South-South', 'region_South-West']
